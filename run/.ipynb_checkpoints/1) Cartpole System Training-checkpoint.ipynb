# %% [markdown]
# # Cartpole System Training

# %%
import gym
import numpy as np
import tensorflow as tf
import pickle
import os
from os import path

# %%
TOTAL_STEPS = 5000
TRAINING_STEPS = 4000
BATCH_SIZE = 64

# %% [markdown]
# ## Cartpole-v0 Info
# ### Action Space
#     The action is a `ndarray` with shape `(1,)` which can take values `{0, 1}` indicating the direction of the fixed force the cart is pushed with.
#     | Num | Action                 |
#     |-----|------------------------|
#     | 0   | Push cart to the left  |
#     | 1   | Push cart to the right |
#
# ### Observation Space
#     The observation is a `ndarray` with shape `(4,)` with the values corresponding to the following positions and velocities:
#     | Num | Observation           | Min                  | Max                |
#     |-----|-----------------------|----------------------|--------------------|
#     | 0   | Cart Position         | -4.8                 | 4.8                |
#     | 1   | Cart Velocity         | -Inf                 | Inf                |
#     | 2   | Pole Angle            | ~ -0.418 rad (-24°)  | ~ 0.418 rad (24°)  |
#     | 3   | Pole Angular Velocity | -Inf                 | Inf                |
#
# (https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py)

# %%
env = gym.make('CartPole-v0')
X = np.empty((TOTAL_STEPS, 4)) # len(env.observation_space.sample()) == 4
U = np.empty((TOTAL_STEPS, 1))
y = np.empty((TOTAL_STEPS, 4))

# %%
tf.random.set_seed(1)
np.random.seed(1)

# %% [markdown]
# ## Sample Trajectories

# %% [markdown]
# Controller input $u$ is set as a binary choice of (-1, 1) for (left, right)

# %%
x_present = env.reset()
for num_timestep in range(TOTAL_STEPS):
    u = env.action_space.sample() # sidenote: should this be one-hot encoded?
    x_prime, _, done, _ = env.step(u)

    # sample x[n], u[n], and x[n+1]
    if u == 0:
        u = -1
    X[num_timestep] = x_present
    U[num_timestep] = u
    y[num_timestep] = x_prime
    x_present = x_prime
    if done:
        x_present = env.reset()
env.close()

# %%
#### "Let-it-run method" ####
for iteration in range(TOTAL_STEPS // 1000):
    x_present = env.reset()
    for timestep in range(1000):
        u = env.action_space.sample()
        x_prime, _, done, _ = env.step(u)

        # sample x[n], u[n], and x[n+1]
        if u == 0:
            u = -1
        X[1000 * iteration + timestep] = x_present
        U[1000 * iteration + timestep] = u
        y[1000 * iteration + timestep] = x_prime
        x_present = x_prime
env.close()

# %% [markdown]
# ## Tensorflow Dataset

# %%
if not path.exists('./cartpole_system_model'):
  os.mkdir('./cartpole_system_model')

# %%
# create tensorflow dataset object instance; concat X and y
dataset_xu = tf.data.Dataset.from_tensor_slices((X, U))
dataset_y = tf.data.Dataset.from_tensor_slices(y)
dataset = tf.data.Dataset.zip((dataset_xu, dataset_y)).shuffle(1000, reshuffle_each_iteration = False)
print(dataset)
# split trajectories into training and testing (no validation)
dataset_training = dataset.take(TRAINING_STEPS)
dataset_testing = dataset.skip(TRAINING_STEPS)
# split training data into batches
dataset_training = dataset_training.repeat(5).batch(BATCH_SIZE)
print(dataset_training)
print(dataset_testing)
# Out:
# <ShuffleDataset shapes: (((4,), (1,)), (4,)), types: ((tf.float64, tf.float64), tf.float64)>
# <BatchDataset shapes: (((None, 4), (None, 1)), (None, 4)), types: ((tf.float64, tf.float64), tf.float64)>
# <SkipDataset shapes: (((4,), (1,)), (4,)), types: ((tf.float64, tf.float64), tf.float64)>
# 2022-03-15 00:59:15.674241: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# ShuffleDataset inner workings
print(dataset)
print(dataset.as_numpy_iterator())
for x, i in dataset.as_numpy_iterator():
    print("X and U Sample")
    print(x[0])
    print(x[1])
    print("X Prime Sample")
    print(i)
    break
# Out:
# <ShuffleDataset shapes: (((4,), (1,)), (4,)), types: ((tf.float64, tf.float64), tf.float64)>
# <tensorflow.python.data.ops.dataset_ops._NumpyIterator object at 0x7f8c914a9670>
# X and U Sample
# [ 0.03569881 -0.20724778 -0.01433196  0.26277724]
# [-1.]
# X Prime Sample
# [ 0.03155385 -0.40216225 -0.00907642  0.55090547]

# %%
# BatchDataset / TakeDataset inner workings
print(dataset_training)
for x, i in dataset_training.as_numpy_iterator():
    print("Batch Size: ", len(x[0]))
    print("X and U Sample")
    print(x[0][0], x[1][0])
    print("X Prime Sample")
    print(i[0])
    break
# Out:
# <BatchDataset shapes: (((None, 4), (None, 1)), (None, 4)), types: ((tf.float64, tf.float64), tf.float64)>
# Batch Size:  64
# X and U Sample
# [ 0.03569881 -0.20724778 -0.01433196  0.26277724] [-1.]
# X Prime Sample
# [ 0.03155385 -0.40216225 -0.00907642  0.55090547]

# %%
# SkipDataset inner workings
print(dataset_testing)
for x, i in dataset_testing.as_numpy_iterator():
    print("Repetition: ", len(x[0]))
    print("X and U Sample")
    print(x[0], x[1])
    print("X Prime Sample")
    print(i)
    break
# Out:
# <SkipDataset shapes: (((4,), (1,)), (4,)), types: ((tf.float64, tf.float64), tf.float64)>
# Repetition:  4
# X and U Sample
# [ 0.02482882 -0.18662952  0.03150921  0.2973583 ] [1.]
# X Prime Sample
# [0.02109623 0.00802943 0.03745638 0.014777  ]

# %%
# tf.data.experimental.save() and load() are deprecated and buggy with Tensorflow 2.
# tf.data.experimental.save(dataset_training, './cartpole_system_model/dataset_training')
# tf.data.experimental.save(dataset_testing, './cartpole_system_model/dataset_testing')
# tf.data.experimental.save(dataset, './cartpole_system_model/dataset')

# %% [markdown]
# ## Model Definition and Training

# %%
class CartpoleLinearControlSystem(tf.keras.Model):
    def __init__(self):
        super(CartpoleLinearControlSystem, self).__init__()
        self.A = tf.keras.layers.Dense(4, input_shape = (4, ), 
                                       activation = 'linear', 
                                       use_bias = False, # Dense is meant to be used as NN layer
                                       name = 'A')
        
        self.B = tf.keras.layers.Dense(4, input_shape = (1, ), 
                                       activation = 'linear', 
                                       use_bias = False, 
                                       name = 'B')
        
        self.add = tf.keras.layers.Add()
        
    def call(self, inputs):
        x, u = inputs
        return self.A(x) + self.B(u)

# %% [markdown]
# Uses reference code in *Python Machine Learning: 3rd Edition* (Raschka and Mirjalili, 2019) pp. 438, 512-515

# %%
# compile model
model = CartpoleLinearControlSystem()
model.compile(tf.keras.optimizers.Adam(),
              loss = tf.keras.losses.MeanSquaredError(),
              metrics = [tf.keras.metrics.MeanSquaredError()])
history = model.fit(dataset_training, epochs = 1000)
tf.keras.models.save_model(
    model, './cartpole_system_model', overwrite = True, include_optimizer = True, save_format = None,
    signatures = None, options = None, save_traces = True
)
# Out:
# Epoch 1/1000
# 313/313 [==============================] - 1s 1ms/step - loss: 0.5755 - mean_squared_error: 0.5755
# Epoch 2/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2495 - mean_squared_error: 0.2495
# Epoch 3/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 0.1023 - mean_squared_error: 0.1023
# Epoch 4/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0402 - mean_squared_error: 0.0402
# Epoch 5/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0164 - mean_squared_error: 0.0164
# Epoch 6/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 7/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 8/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 9/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0035 - mean_squared_error: 0.0035
# Epoch 10/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 11/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 12/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 13/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 14/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 15/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 16/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 17/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 18/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 9.2330e-04 - mean_squared_error: 9.2330e-04
# Epoch 19/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.3483e-04 - mean_squared_error: 8.3483e-04
# Epoch 20/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 7.5804e-04 - mean_squared_error: 7.5804e-04
# Epoch 21/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 6.8749e-04 - mean_squared_error: 6.8749e-04
# Epoch 22/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 6.1978e-04 - mean_squared_error: 6.1978e-04
# Epoch 23/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 5.5339e-04 - mean_squared_error: 5.5339e-04
# Epoch 24/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 4.8815e-04 - mean_squared_error: 4.8815e-04
# Epoch 25/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 4.2461e-04 - mean_squared_error: 4.2461e-04
# Epoch 26/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 3.6363e-04 - mean_squared_error: 3.6363e-04
# Epoch 27/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 3.0614e-04 - mean_squared_error: 3.0614e-04
# Epoch 28/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 2.5294e-04 - mean_squared_error: 2.5294e-04
# Epoch 29/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 2.0468e-04 - mean_squared_error: 2.0468e-04
# Epoch 30/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 1.6182e-04 - mean_squared_error: 1.6182e-04
# Epoch 31/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 1.2461e-04 - mean_squared_error: 1.2461e-04
# Epoch 32/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 9.3105e-05 - mean_squared_error: 9.3105e-05
# Epoch 33/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 6.7163e-05 - mean_squared_error: 6.7163e-05
# Epoch 34/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 4.6506e-05 - mean_squared_error: 4.6506e-05
# Epoch 35/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 3.0711e-05 - mean_squared_error: 3.0711e-05
# Epoch 36/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 1.9216e-05 - mean_squared_error: 1.9216e-05
# Epoch 37/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 1.1342e-05 - mean_squared_error: 1.1342e-05
# Epoch 38/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 6.3316e-06 - mean_squared_error: 6.3316e-06
# Epoch 39/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 3.4191e-06 - mean_squared_error: 3.4191e-06
# Epoch 40/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 1.9012e-06 - mean_squared_error: 1.9012e-06
# Epoch 41/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 1.2065e-06 - mean_squared_error: 1.2065e-06
# Epoch 42/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 9.3470e-07 - mean_squared_error: 9.3470e-07
# Epoch 43/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.4736e-07 - mean_squared_error: 8.4736e-07
# Epoch 44/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.2532e-07 - mean_squared_error: 8.2532e-07
# Epoch 45/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.2101e-07 - mean_squared_error: 8.2101e-07
# Epoch 46/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.2049e-07 - mean_squared_error: 8.2049e-07
# Epoch 47/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.2845e-07 - mean_squared_error: 8.2845e-07
# Epoch 48/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.2767e-07 - mean_squared_error: 8.2767e-07
# Epoch 49/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.2628e-07 - mean_squared_error: 8.2628e-07
# Epoch 50/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.3366e-07 - mean_squared_error: 8.3366e-07
# Epoch 51/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.3690e-07 - mean_squared_error: 8.3690e-07
# Epoch 52/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5103e-07 - mean_squared_error: 8.5103e-07
# Epoch 53/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.4463e-07 - mean_squared_error: 8.4463e-07
# Epoch 54/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.4889e-07 - mean_squared_error: 8.4889e-07
# Epoch 55/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.4592e-07 - mean_squared_error: 8.4592e-07
# Epoch 56/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.4705e-07 - mean_squared_error: 8.4705e-07
# Epoch 57/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5477e-07 - mean_squared_error: 8.5477e-07
# Epoch 58/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5434e-07 - mean_squared_error: 8.5434e-07
# Epoch 59/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5038e-07 - mean_squared_error: 8.5038e-07
# Epoch 60/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5175e-07 - mean_squared_error: 8.5175e-07
# Epoch 61/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5447e-07 - mean_squared_error: 8.5447e-07
# Epoch 62/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6096e-07 - mean_squared_error: 8.6096e-07
# Epoch 63/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5435e-07 - mean_squared_error: 8.5435e-07
# Epoch 64/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5198e-07 - mean_squared_error: 8.5198e-07
# Epoch 65/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5236e-07 - mean_squared_error: 8.5236e-07
# Epoch 66/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6573e-07 - mean_squared_error: 8.6573e-07
# Epoch 67/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5680e-07 - mean_squared_error: 8.5680e-07
# Epoch 68/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5212e-07 - mean_squared_error: 8.5212e-07
# Epoch 69/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5213e-07 - mean_squared_error: 8.5213e-07
# Epoch 70/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5642e-07 - mean_squared_error: 8.5642e-07
# Epoch 71/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5213e-07 - mean_squared_error: 8.5213e-07
# Epoch 72/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5820e-07 - mean_squared_error: 8.5820e-07
# Epoch 73/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5545e-07 - mean_squared_error: 8.5545e-07
# Epoch 74/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5705e-07 - mean_squared_error: 8.5705e-07
# Epoch 75/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5232e-07 - mean_squared_error: 8.5232e-07
# Epoch 76/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5538e-07 - mean_squared_error: 8.5538e-07
# Epoch 77/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5220e-07 - mean_squared_error: 8.5220e-07
# Epoch 78/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6774e-07 - mean_squared_error: 8.6774e-07
# Epoch 79/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 80/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 81/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5264e-07 - mean_squared_error: 8.5264e-07
# Epoch 82/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5666e-07 - mean_squared_error: 8.5666e-07
# Epoch 83/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5578e-07 - mean_squared_error: 8.5578e-07
# Epoch 84/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5574e-07 - mean_squared_error: 8.5574e-07
# Epoch 85/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 86/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.6068e-07 - mean_squared_error: 8.6068e-07
# Epoch 87/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5474e-07 - mean_squared_error: 8.5474e-07
# Epoch 88/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 89/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5888e-07 - mean_squared_error: 8.5888e-07
# Epoch 90/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5652e-07 - mean_squared_error: 8.5652e-07
# Epoch 91/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5225e-07 - mean_squared_error: 8.5225e-07
# Epoch 92/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 93/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5998e-07 - mean_squared_error: 8.5998e-07
# Epoch 94/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5275e-07 - mean_squared_error: 8.5275e-07
# Epoch 95/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5850e-07 - mean_squared_error: 8.5850e-07
# Epoch 96/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5270e-07 - mean_squared_error: 8.5270e-07
# Epoch 97/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5771e-07 - mean_squared_error: 8.5771e-07
# Epoch 98/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 99/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.6289e-07 - mean_squared_error: 8.6289e-07
# Epoch 100/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 101/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5893e-07 - mean_squared_error: 8.5893e-07
# Epoch 102/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07: 0s - loss: 8.5310e-07 - mean_squared_error: 8.5310
# Epoch 103/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 104/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5925e-07 - mean_squared_error: 8.5925e-07
# Epoch 105/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6017e-07 - mean_squared_error: 8.6017e-07
# Epoch 106/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5217e-07 - mean_squared_error: 8.5217e-07
# Epoch 107/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 108/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5277e-07 - mean_squared_error: 8.5277e-07
# Epoch 109/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.7261e-07 - mean_squared_error: 8.7261e-07
# Epoch 110/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 111/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 112/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5217e-07 - mean_squared_error: 8.5217e-07
# Epoch 113/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5665e-07 - mean_squared_error: 8.5665e-07
# Epoch 114/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5220e-07 - mean_squared_error: 8.5220e-07
# Epoch 115/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5999e-07 - mean_squared_error: 8.5999e-07
# Epoch 116/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5215e-07 - mean_squared_error: 8.5215e-07
# Epoch 117/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6017e-07 - mean_squared_error: 8.6017e-07
# Epoch 118/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5331e-07 - mean_squared_error: 8.5331e-07
# Epoch 119/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 120/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5505e-07 - mean_squared_error: 8.5505e-07
# Epoch 121/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6256e-07 - mean_squared_error: 8.6256e-07
# Epoch 122/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5475e-07 - mean_squared_error: 8.5475e-07
# Epoch 123/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 124/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6086e-07 - mean_squared_error: 8.6086e-07
# Epoch 125/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5297e-07 - mean_squared_error: 8.5297e-07
# Epoch 126/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6329e-07 - mean_squared_error: 8.6329e-07
# Epoch 127/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5254e-07 - mean_squared_error: 8.5254e-07
# Epoch 128/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 129/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5702e-07 - mean_squared_error: 8.5702e-07
# Epoch 130/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5215e-07 - mean_squared_error: 8.5215e-07
# Epoch 131/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 132/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6824e-07 - mean_squared_error: 8.6824e-07
# Epoch 133/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5215e-07 - mean_squared_error: 8.5215e-07
# Epoch 134/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 135/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5583e-07 - mean_squared_error: 8.5583e-07
# Epoch 136/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5272e-07 - mean_squared_error: 8.5272e-07
# Epoch 137/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5687e-07 - mean_squared_error: 8.5687e-07
# Epoch 138/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5389e-07 - mean_squared_error: 8.5389e-07
# Epoch 139/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5446e-07 - mean_squared_error: 8.5446e-07
# Epoch 140/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6086e-07 - mean_squared_error: 8.6086e-07
# Epoch 141/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6165e-07 - mean_squared_error: 8.6165e-07
# Epoch 142/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 143/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 144/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5540e-07 - mean_squared_error: 8.5540e-07
# Epoch 145/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5226e-07 - mean_squared_error: 8.5226e-07
# Epoch 146/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5539e-07 - mean_squared_error: 8.5539e-07
# Epoch 147/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5450e-07 - mean_squared_error: 8.5450e-07
# Epoch 148/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5955e-07 - mean_squared_error: 8.5955e-07
# Epoch 149/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5658e-07 - mean_squared_error: 8.5658e-07
# Epoch 150/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5515e-07 - mean_squared_error: 8.5515e-07
# Epoch 151/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5215e-07 - mean_squared_error: 8.5215e-07
# Epoch 152/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5569e-07 - mean_squared_error: 8.5569e-07
# Epoch 153/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5219e-07 - mean_squared_error: 8.5219e-07
# Epoch 154/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.6288e-07 - mean_squared_error: 8.6288e-07
# Epoch 155/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5216e-07 - mean_squared_error: 8.5216e-07
# Epoch 156/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 157/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5304e-07 - mean_squared_error: 8.5304e-07
# Epoch 158/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.6105e-07 - mean_squared_error: 8.6105e-07
# Epoch 159/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 160/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5636e-07 - mean_squared_error: 8.5636e-07
# Epoch 161/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5860e-07 - mean_squared_error: 8.5860e-07
# Epoch 162/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5278e-07 - mean_squared_error: 8.5278e-07
# Epoch 163/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5650e-07 - mean_squared_error: 8.5650e-07
# Epoch 164/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5217e-07 - mean_squared_error: 8.5217e-07
# Epoch 165/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 166/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5675e-07 - mean_squared_error: 8.5675e-07
# Epoch 167/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6169e-07 - mean_squared_error: 8.6169e-07
# Epoch 168/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5300e-07 - mean_squared_error: 8.5300e-07
# Epoch 169/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6373e-07 - mean_squared_error: 8.6373e-07
# Epoch 170/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 171/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5286e-07 - mean_squared_error: 8.5286e-07
# Epoch 172/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5549e-07 - mean_squared_error: 8.5549e-07
# Epoch 173/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 174/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.6510e-07 - mean_squared_error: 8.6510e-07
# Epoch 175/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 176/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 177/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5300e-07 - mean_squared_error: 8.5300e-07
# Epoch 178/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5785e-07 - mean_squared_error: 8.5785e-07
# Epoch 179/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5824e-07 - mean_squared_error: 8.5824e-07
# Epoch 180/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 181/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5250e-07 - mean_squared_error: 8.5250e-07
# Epoch 182/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.7029e-07 - mean_squared_error: 8.7029e-07
# Epoch 183/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5263e-07 - mean_squared_error: 8.5263e-07
# Epoch 184/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 185/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5222e-07 - mean_squared_error: 8.5222e-07
# Epoch 186/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6192e-07 - mean_squared_error: 8.6192e-07
# Epoch 187/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5218e-07 - mean_squared_error: 8.5218e-07
# Epoch 188/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6128e-07 - mean_squared_error: 8.6128e-07
# Epoch 189/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 190/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5236e-07 - mean_squared_error: 8.5236e-07
# Epoch 191/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5560e-07 - mean_squared_error: 8.5560e-07
# Epoch 192/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 193/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5898e-07 - mean_squared_error: 8.5898e-07
# Epoch 194/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5861e-07 - mean_squared_error: 8.5861e-07
# Epoch 195/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 196/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5263e-07 - mean_squared_error: 8.5263e-07
# Epoch 197/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5530e-07 - mean_squared_error: 8.5530e-07
# Epoch 198/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5833e-07 - mean_squared_error: 8.5833e-07
# Epoch 199/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5699e-07 - mean_squared_error: 8.5699e-07
# Epoch 200/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 201/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 202/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6687e-07 - mean_squared_error: 8.6687e-07
# Epoch 203/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5989e-07 - mean_squared_error: 8.5989e-07
# Epoch 204/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 205/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 206/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 207/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6104e-07 - mean_squared_error: 8.6104e-07
# Epoch 208/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.7372e-07 - mean_squared_error: 8.7372e-07
# Epoch 209/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5219e-07 - mean_squared_error: 8.5219e-07
# Epoch 210/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 211/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 212/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5354e-07 - mean_squared_error: 8.5354e-07
# Epoch 213/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5442e-07 - mean_squared_error: 8.5442e-07
# Epoch 214/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5583e-07 - mean_squared_error: 8.5583e-07
# Epoch 215/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.7109e-07 - mean_squared_error: 8.7109e-07
# Epoch 216/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 217/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5632e-07 - mean_squared_error: 8.5632e-07
# Epoch 218/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5217e-07 - mean_squared_error: 8.5217e-07
# Epoch 219/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5414e-07 - mean_squared_error: 8.5414e-07
# Epoch 220/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 221/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5640e-07 - mean_squared_error: 8.5640e-07
# Epoch 222/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5544e-07 - mean_squared_error: 8.5544e-07
# Epoch 223/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5223e-07 - mean_squared_error: 8.5223e-07
# Epoch 224/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.7761e-07 - mean_squared_error: 8.7761e-07
# Epoch 225/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5240e-07 - mean_squared_error: 8.5240e-07
# Epoch 226/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5840e-07 - mean_squared_error: 8.5840e-07
# Epoch 227/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 228/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 229/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 230/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5988e-07 - mean_squared_error: 8.5988e-07
# Epoch 231/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5217e-07 - mean_squared_error: 8.5217e-07
# Epoch 232/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5560e-07 - mean_squared_error: 8.5560e-07
# Epoch 233/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 234/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5644e-07 - mean_squared_error: 8.5644e-07
# Epoch 235/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5569e-07 - mean_squared_error: 8.5569e-07
# Epoch 236/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5231e-07 - mean_squared_error: 8.5231e-07
# Epoch 237/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6025e-07 - mean_squared_error: 8.6025e-07
# Epoch 238/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5748e-07 - mean_squared_error: 8.5748e-07
# Epoch 239/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 240/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6286e-07 - mean_squared_error: 8.6286e-07
# Epoch 241/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5224e-07 - mean_squared_error: 8.5224e-07
# Epoch 242/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5689e-07 - mean_squared_error: 8.5689e-07
# Epoch 243/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 244/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 245/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5535e-07 - mean_squared_error: 8.5535e-07
# Epoch 246/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5781e-07 - mean_squared_error: 8.5781e-07
# Epoch 247/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5446e-07 - mean_squared_error: 8.5446e-07
# Epoch 248/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5472e-07 - mean_squared_error: 8.5472e-07
# Epoch 249/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5272e-07 - mean_squared_error: 8.5272e-07
# Epoch 250/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5781e-07 - mean_squared_error: 8.5781e-07
# Epoch 251/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5690e-07 - mean_squared_error: 8.5690e-07
# Epoch 252/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5222e-07 - mean_squared_error: 8.5222e-07
# Epoch 253/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6051e-07 - mean_squared_error: 8.6051e-07
# Epoch 254/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5513e-07 - mean_squared_error: 8.5513e-07
# Epoch 255/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 256/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5876e-07 - mean_squared_error: 8.5876e-07
# Epoch 257/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 258/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6371e-07 - mean_squared_error: 8.6371e-07
# Epoch 259/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 260/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5654e-07 - mean_squared_error: 8.5654e-07
# Epoch 261/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 262/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 263/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6249e-07 - mean_squared_error: 8.6249e-07
# Epoch 264/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5404e-07 - mean_squared_error: 8.5404e-07
# Epoch 265/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 266/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5243e-07 - mean_squared_error: 8.5243e-07
# Epoch 267/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5570e-07 - mean_squared_error: 8.5570e-07
# Epoch 268/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5566e-07 - mean_squared_error: 8.5566e-07
# Epoch 269/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6055e-07 - mean_squared_error: 8.6055e-07
# Epoch 270/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5447e-07 - mean_squared_error: 8.5447e-07
# Epoch 271/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5577e-07 - mean_squared_error: 8.5577e-07
# Epoch 272/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 273/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6001e-07 - mean_squared_error: 8.6001e-07
# Epoch 274/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5586e-07 - mean_squared_error: 8.5586e-07
# Epoch 275/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 276/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5698e-07 - mean_squared_error: 8.5698e-07
# Epoch 277/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5357e-07 - mean_squared_error: 8.5357e-07
# Epoch 278/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5601e-07 - mean_squared_error: 8.5601e-07
# Epoch 279/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5554e-07 - mean_squared_error: 8.5554e-07
# Epoch 280/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5274e-07 - mean_squared_error: 8.5274e-07
# Epoch 281/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6381e-07 - mean_squared_error: 8.6381e-07
# Epoch 282/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6192e-07 - mean_squared_error: 8.6192e-07
# Epoch 283/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 284/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 285/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 286/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6054e-07 - mean_squared_error: 8.6054e-07
# Epoch 287/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5935e-07 - mean_squared_error: 8.5935e-07
# Epoch 288/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 289/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 290/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5215e-07 - mean_squared_error: 8.5215e-07
# Epoch 291/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6598e-07 - mean_squared_error: 8.6598e-07
# Epoch 292/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5217e-07 - mean_squared_error: 8.5217e-07
# Epoch 293/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 294/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5615e-07 - mean_squared_error: 8.5615e-07
# Epoch 295/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5885e-07 - mean_squared_error: 8.5885e-07
# Epoch 296/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 297/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6027e-07 - mean_squared_error: 8.6027e-07
# Epoch 298/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 299/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5720e-07 - mean_squared_error: 8.5720e-07
# Epoch 300/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5213e-07 - mean_squared_error: 8.5213e-07
# Epoch 301/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 302/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.7524e-07 - mean_squared_error: 8.7524e-07
# Epoch 303/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5853e-07 - mean_squared_error: 8.5853e-07
# Epoch 304/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5213e-07 - mean_squared_error: 8.5213e-07
# Epoch 305/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 306/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5248e-07 - mean_squared_error: 8.5248e-07
# Epoch 307/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5912e-07 - mean_squared_error: 8.5912e-07
# Epoch 308/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 309/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5534e-07 - mean_squared_error: 8.5534e-07
# Epoch 310/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5229e-07 - mean_squared_error: 8.5229e-07
# Epoch 311/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6090e-07 - mean_squared_error: 8.6090e-07
# Epoch 312/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5215e-07 - mean_squared_error: 8.5215e-07
# Epoch 313/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6107e-07 - mean_squared_error: 8.6107e-07
# Epoch 314/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5625e-07 - mean_squared_error: 8.5625e-07
# Epoch 315/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 316/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5250e-07 - mean_squared_error: 8.5250e-07
# Epoch 317/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6327e-07 - mean_squared_error: 8.6327e-07
# Epoch 318/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6197e-07 - mean_squared_error: 8.6197e-07
# Epoch 319/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 320/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5213e-07 - mean_squared_error: 8.5213e-07
# Epoch 321/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 322/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5587e-07 - mean_squared_error: 8.5587e-07
# Epoch 323/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6243e-07 - mean_squared_error: 8.6243e-07
# Epoch 324/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 325/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5630e-07 - mean_squared_error: 8.5630e-07
# Epoch 326/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5215e-07 - mean_squared_error: 8.5215e-07
# Epoch 327/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5615e-07 - mean_squared_error: 8.5615e-07
# Epoch 328/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5311e-07 - mean_squared_error: 8.5311e-07
# Epoch 329/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.6336e-07 - mean_squared_error: 8.6336e-07
# Epoch 330/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5394e-07 - mean_squared_error: 8.5394e-07
# Epoch 331/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5849e-07 - mean_squared_error: 8.5849e-07
# Epoch 332/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 333/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 334/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6200e-07 - mean_squared_error: 8.6200e-07
# Epoch 335/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5610e-07 - mean_squared_error: 8.5610e-07
# Epoch 336/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5226e-07 - mean_squared_error: 8.5226e-07
# Epoch 337/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 338/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5238e-07 - mean_squared_error: 8.5238e-07
# Epoch 339/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.7149e-07 - mean_squared_error: 8.7149e-07
# Epoch 340/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 341/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 342/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 343/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5299e-07 - mean_squared_error: 8.5299e-07
# Epoch 344/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.6479e-07 - mean_squared_error: 8.6479e-07
# Epoch 345/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5215e-07 - mean_squared_error: 8.5215e-07
# Epoch 346/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 347/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5296e-07 - mean_squared_error: 8.5296e-07
# Epoch 348/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6460e-07 - mean_squared_error: 8.6460e-07
# Epoch 349/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5215e-07 - mean_squared_error: 8.5215e-07
# Epoch 350/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 351/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6390e-07 - mean_squared_error: 8.6390e-07
# Epoch 352/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5638e-07 - mean_squared_error: 8.5638e-07
# Epoch 353/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 354/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5709e-07 - mean_squared_error: 8.5709e-07
# Epoch 355/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5536e-07 - mean_squared_error: 8.5536e-07
# Epoch 356/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5233e-07 - mean_squared_error: 8.5233e-07
# Epoch 357/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5667e-07 - mean_squared_error: 8.5667e-07
# Epoch 358/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 359/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6470e-07 - mean_squared_error: 8.6470e-07
# Epoch 360/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5858e-07 - mean_squared_error: 8.5858e-07
# Epoch 361/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 362/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 363/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 364/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6209e-07 - mean_squared_error: 8.6209e-07
# Epoch 365/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5873e-07 - mean_squared_error: 8.5873e-07
# Epoch 366/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 367/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 368/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 369/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6499e-07 - mean_squared_error: 8.6499e-07
# Epoch 370/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5221e-07 - mean_squared_error: 8.5221e-07
# Epoch 371/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 372/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5445e-07 - mean_squared_error: 8.5445e-07
# Epoch 373/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5355e-07 - mean_squared_error: 8.5355e-07
# Epoch 374/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6035e-07 - mean_squared_error: 8.6035e-07
# Epoch 375/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5237e-07 - mean_squared_error: 8.5237e-07
# Epoch 376/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5234e-07 - mean_squared_error: 8.5234e-07
# Epoch 377/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6039e-07 - mean_squared_error: 8.6039e-07
# Epoch 378/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5271e-07 - mean_squared_error: 8.5271e-07
# Epoch 379/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5467e-07 - mean_squared_error: 8.5467e-07
# Epoch 380/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5472e-07 - mean_squared_error: 8.5472e-07
# Epoch 381/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5377e-07 - mean_squared_error: 8.5377e-07
# Epoch 382/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6202e-07 - mean_squared_error: 8.6202e-07
# Epoch 383/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5224e-07 - mean_squared_error: 8.5224e-07
# Epoch 384/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5215e-07 - mean_squared_error: 8.5215e-07
# Epoch 385/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5794e-07 - mean_squared_error: 8.5794e-07
# Epoch 386/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5799e-07 - mean_squared_error: 8.5799e-07
# Epoch 387/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5220e-07 - mean_squared_error: 8.5220e-07
# Epoch 388/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5215e-07 - mean_squared_error: 8.5215e-07
# Epoch 389/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5801e-07 - mean_squared_error: 8.5801e-07
# Epoch 390/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5583e-07 - mean_squared_error: 8.5583e-07
# Epoch 391/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5245e-07 - mean_squared_error: 8.5245e-07
# Epoch 392/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6052e-07 - mean_squared_error: 8.6052e-07
# Epoch 393/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5557e-07 - mean_squared_error: 8.5557e-07
# Epoch 394/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5222e-07 - mean_squared_error: 8.5222e-07
# Epoch 395/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5897e-07 - mean_squared_error: 8.5897e-07
# ...
# Epoch 876/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5513e-07 - mean_squared_error: 8.5513e-07
# Epoch 877/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5516e-07 - mean_squared_error: 8.5516e-07
# Epoch 878/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5306e-07 - mean_squared_error: 8.5306e-07
# Epoch 879/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5998e-07 - mean_squared_error: 8.5998e-07
# Epoch 880/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5215e-07 - mean_squared_error: 8.5215e-07
# Epoch 881/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5217e-07 - mean_squared_error: 8.5217e-07
# Epoch 882/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5510e-07 - mean_squared_error: 8.5510e-07
# Epoch 883/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.6095e-07 - mean_squared_error: 8.6095e-07
# Epoch 884/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5511e-07 - mean_squared_error: 8.5511e-07
# Epoch 885/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5867e-07 - mean_squared_error: 8.5867e-07
# Epoch 886/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 887/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 888/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5647e-07 - mean_squared_error: 8.5647e-07
# Epoch 889/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5502e-07 - mean_squared_error: 8.5502e-07
# Epoch 890/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5703e-07 - mean_squared_error: 8.5703e-07
# Epoch 891/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5521e-07 - mean_squared_error: 8.5521e-07
# Epoch 892/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5231e-07 - mean_squared_error: 8.5231e-07
# Epoch 893/1000
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5725e-07 - mean_squared_error: 8.5725e-07
# Epoch 894/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.6061e-07 - mean_squared_error: 8.6061e-07
# Epoch 895/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5215e-07 - mean_squared_error: 8.5215e-07
# Epoch 896/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6268e-07 - mean_squared_error: 8.6268e-07
# Epoch 897/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 898/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5524e-07 - mean_squared_error: 8.5524e-07
# Epoch 899/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5221e-07 - mean_squared_error: 8.5221e-07
# Epoch 900/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5376e-07 - mean_squared_error: 8.5376e-07
# Epoch 901/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5602e-07 - mean_squared_error: 8.5602e-07
# Epoch 902/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5555e-07 - mean_squared_error: 8.5555e-07
# Epoch 903/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5760e-07 - mean_squared_error: 8.5760e-07
# Epoch 904/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5841e-07 - mean_squared_error: 8.5841e-07
# Epoch 905/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5439e-07 - mean_squared_error: 8.5439e-07
# Epoch 906/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5475e-07 - mean_squared_error: 8.5475e-07
# Epoch 907/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5266e-07 - mean_squared_error: 8.5266e-07
# Epoch 908/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5736e-07 - mean_squared_error: 8.5736e-07
# Epoch 909/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.7223e-07 - mean_squared_error: 8.7223e-07
# Epoch 910/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5231e-07 - mean_squared_error: 8.5231e-07
# Epoch 911/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5213e-07 - mean_squared_error: 8.5213e-07
# Epoch 912/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5910e-07 - mean_squared_error: 8.5910e-07
# Epoch 913/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5221e-07 - mean_squared_error: 8.5221e-07
# Epoch 914/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 915/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 916/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5285e-07 - mean_squared_error: 8.5285e-07
# Epoch 917/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6699e-07 - mean_squared_error: 8.6699e-07
# Epoch 918/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 919/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 920/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5712e-07 - mean_squared_error: 8.5712e-07
# Epoch 921/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6439e-07 - mean_squared_error: 8.6439e-07
# Epoch 922/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5293e-07 - mean_squared_error: 8.5293e-07
# Epoch 923/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6909e-07 - mean_squared_error: 8.6909e-07
# Epoch 924/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5238e-07 - mean_squared_error: 8.5238e-07
# Epoch 925/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 926/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5213e-07 - mean_squared_error: 8.5213e-07
# Epoch 927/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5660e-07 - mean_squared_error: 8.5660e-07
# Epoch 928/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5221e-07 - mean_squared_error: 8.5221e-07
# Epoch 929/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 930/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6334e-07 - mean_squared_error: 8.6334e-07
# Epoch 931/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5215e-07 - mean_squared_error: 8.5215e-07
# Epoch 932/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5573e-07 - mean_squared_error: 8.5573e-07
# Epoch 933/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 934/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6165e-07 - mean_squared_error: 8.6165e-07
# Epoch 935/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5499e-07 - mean_squared_error: 8.5499e-07
# Epoch 936/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 937/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6103e-07 - mean_squared_error: 8.6103e-07
# Epoch 938/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 939/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5730e-07 - mean_squared_error: 8.5730e-07
# Epoch 940/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 941/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5522e-07 - mean_squared_error: 8.5522e-07
# Epoch 942/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6075e-07 - mean_squared_error: 8.6075e-07
# Epoch 943/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5284e-07 - mean_squared_error: 8.5284e-07
# Epoch 944/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5548e-07 - mean_squared_error: 8.5548e-07
# Epoch 945/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 946/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5773e-07 - mean_squared_error: 8.5773e-07
# Epoch 947/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6952e-07 - mean_squared_error: 8.6952e-07
# Epoch 948/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 949/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5224e-07 - mean_squared_error: 8.5224e-07
# Epoch 950/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5647e-07 - mean_squared_error: 8.5647e-07
# Epoch 951/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5213e-07 - mean_squared_error: 8.5213e-07
# Epoch 952/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5215e-07 - mean_squared_error: 8.5215e-07
# Epoch 953/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5712e-07 - mean_squared_error: 8.5712e-07
# Epoch 954/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6278e-07 - mean_squared_error: 8.6278e-07
# Epoch 955/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 956/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5704e-07 - mean_squared_error: 8.5704e-07
# Epoch 957/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 958/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5516e-07 - mean_squared_error: 8.5516e-07
# Epoch 959/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.6051e-07 - mean_squared_error: 8.6051e-07
# Epoch 960/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5478e-07 - mean_squared_error: 8.5478e-07
# Epoch 961/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5234e-07 - mean_squared_error: 8.5234e-07
# Epoch 962/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5443e-07 - mean_squared_error: 8.5443e-07
# Epoch 963/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6031e-07 - mean_squared_error: 8.6031e-07
# Epoch 964/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5229e-07 - mean_squared_error: 8.5229e-07
# Epoch 965/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5491e-07 - mean_squared_error: 8.5491e-07
# Epoch 966/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5230e-07 - mean_squared_error: 8.5230e-07
# Epoch 967/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5899e-07 - mean_squared_error: 8.5899e-07
# Epoch 968/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5225e-07 - mean_squared_error: 8.5225e-07
# Epoch 969/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5610e-07 - mean_squared_error: 8.5610e-07
# Epoch 970/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6125e-07 - mean_squared_error: 8.6125e-07
# Epoch 971/1000
# 313/313 [==============================] - 0s 2ms/step - loss: 8.5548e-07 - mean_squared_error: 8.5548e-07
# Epoch 972/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5265e-07 - mean_squared_error: 8.5265e-07
# Epoch 973/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 974/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5251e-07 - mean_squared_error: 8.5251e-07
# Epoch 975/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6385e-07 - mean_squared_error: 8.6385e-07
# Epoch 976/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5231e-07 - mean_squared_error: 8.5231e-07
# Epoch 977/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5584e-07 - mean_squared_error: 8.5584e-07
# Epoch 978/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 979/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6310e-07 - mean_squared_error: 8.6310e-07
# Epoch 980/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5229e-07 - mean_squared_error: 8.5229e-07
# Epoch 981/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5827e-07 - mean_squared_error: 8.5827e-07
# Epoch 982/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5279e-07 - mean_squared_error: 8.5279e-07
# Epoch 983/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5218e-07 - mean_squared_error: 8.5218e-07
# Epoch 984/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5720e-07 - mean_squared_error: 8.5720e-07
# Epoch 985/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5219e-07 - mean_squared_error: 8.5219e-07
# Epoch 986/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5606e-07 - mean_squared_error: 8.5606e-07
# Epoch 987/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5246e-07 - mean_squared_error: 8.5246e-07
# Epoch 988/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6459e-07 - mean_squared_error: 8.6459e-07
# Epoch 989/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 990/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# Epoch 991/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5774e-07 - mean_squared_error: 8.5774e-07
# Epoch 992/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5290e-07 - mean_squared_error: 8.5290e-07
# Epoch 993/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5382e-07 - mean_squared_error: 8.5382e-07
# Epoch 994/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5972e-07 - mean_squared_error: 8.5972e-07
# Epoch 995/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5218e-07 - mean_squared_error: 8.5218e-07
# Epoch 996/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5394e-07 - mean_squared_error: 8.5394e-07
# Epoch 997/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.6489e-07 - mean_squared_error: 8.6489e-07
# Epoch 998/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5774e-07 - mean_squared_error: 8.5774e-07
# Epoch 999/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5255e-07 - mean_squared_error: 8.5255e-07
# Epoch 1000/1000
# 313/313 [==============================] - 0s 1ms/step - loss: 8.5214e-07 - mean_squared_error: 8.5214e-07
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.merge.Add object at 0x7f8c914a9b80>, because it is not built.
# INFO:tensorflow:Assets written to: ./cartpole_system_model/assets
# 2022-03-15 01:07:49.848057: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# /Users/johnlime/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)

# %%
with open('./cartpole_system_model/history.pkl', 'wb') as filepath:
    pickle.dump(history, filepath)
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.merge.Add object at 0x7f8c914a9b80>, because it is not built.
# INFO:tensorflow:Assets written to: ram://8db37bad-aadd-4067-8254-b35bced639ef/assets
# /Users/johnlime/anaconda3/lib/python3.8/site-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)

# %% [markdown]
# ## Model Evaluation and Learning Curve Visualization

# %%
model = tf.keras.models.load_model(
    './cartpole_system_model', custom_objects=None, compile=True, options=None
)

history = None
with open('./cartpole_system_model/history.pkl', 'rb') as filepath:
    history = pickle.load(filepath)
    
history_keys = history.history.keys()

# %%
# tf.data.experimental.save() and load() are deprecated and buggy with Tensorflow 2.
# dataset_training = tf.data.experimental.load('./cartpole_system_model/dataset_training')
# dataset_testing = tf.data.experimental.load('./cartpole_system_model/dataset_testing')
# dataset = tf.data.experimental.load('./cartpole_system_model/dataset')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def show_history(history_obj, y_data_name):
    # plt.plot(range(history_obj.params['epochs']), history_obj.history[y_data_name])
    plt.plot(range(100), history_obj.history[y_data_name][:100])
    plt.xlabel("Epochs")
    plt.ylabel(y_data_name)
    plt.savefig('./cartpole_system_model/' + y_data_name + '.png')
    plt.show()

# %%
for i, key in enumerate(history.history.keys()):
  show_history(history, key)

# %%
model.summary()
# Out:
# Model: "cartpole_linear_control_system"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  A (Dense)                   multiple                  16
#
#  B (Dense)                   multiple                  4
#
#  add (Add)                   multiple                  0
#
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________

# %%
prediction_result = model.evaluate(dataset_testing.batch(8))
print(prediction_result)
# Out:
# 125/125 [==============================] - 0s 821us/step - loss: 1.0185e-06 - mean_squared_error: 1.0185e-06
# [1.018538341668318e-06, 1.018538341668318e-06]
